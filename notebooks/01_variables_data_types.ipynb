// %% [markdown]
// # Hello world in Rust

// %% [markdown]
// This is the simplest program you can write in Rust. It simply prints "Hello, world!" to the console.

// %%
// first program in Rust

fn main() {
    println!("Hello, World!");
}

// %%
main();
// Out:
// Hello, World!

// %% [markdown]
// # Comments

// %% [markdown]
// Comments in Rust are similar to comments in other languages. They can be single-line or multi-line.

// %%
// this is a comment

/* this is
   multiline
   comment */

/// this is a doc comment - rustdoc can compile this comments into project documentation

// %% [markdown]
// # Variables and Data Types

// %% [markdown]
// ## Declaring variables
//
// * Variables in Rust are declared using the `let` keyword.
// * Rust is a statically typed language, which means that you need to specify the type of the variable when you declare it:

// %%
let age: u8 = 30;
let pi: f64 = 3.14159;
let is_ok: bool = true;

println!("Age: {}, Pi: {}, Is OK: {}", age, pi, is_ok);
// Out:
// Age: 30, Pi: 3.14159, Is OK: true

// %% [markdown]
// * Or the compiler can infer the type of the variable from the value assigned to it:

// %%
let n = 0; // n: i32
let e = 2.718; // e: f64
let is_done = false; // is_done: bool

let x;
let flag = true;

if flag {
    x = 665;
    println!("x in if: {}", x); // error: use of possibly uninitialized variable `x`
}
else {
    x = 42;
    println!("x in else: {}", x); // error: use of possibly uninitialized variable `x`   
}

println!("x: {}", x); // error: use of possibly uninitialized variable `x`
// Out:
// x in if: 665
// x: 665

// %% [markdown]
// * Variables are **immutable** by default

// %%
let step = 1;
println!("step={}", step);
step = 2
// Out:
// [E0384] Error: cannot assign twice to immutable variable `step`
//    ╭─[ command_23:1:1 ]
//    │
//  1 │ let step = 1;
//    │     ┬─┬─
//    │     ╰───── help: consider making this binding mutable: `mut `
//    │       │
//    │       ╰─── first assignment to `step`
//    │
//    │ Note: You can change an existing variable to mutable like: `let mut x = x;`
// ───╯

// %% [markdown]
// * All variables must be initialized before use

// %%
let id: u32;
println!("id={}", id);
// Out:
// [E0381] Error: used binding `id` isn't initialized
//    ╭─[ command_24:1:1 ]
//    │
//  1 │ let id: u32;
//    │     ─┬     │
//    │      ╰─────── binding declared here but left uninitialized
//    │            │
//    │            ╰─ help: consider assigning a value: ` = 42`
//  2 │ println!("id={}", id);
//    │                   ─┬
//    │                    ╰── `id` used here but it isn't initialized
// ───╯

// %% [markdown]
// * but the initialization can be done later

// %%
let programming_language;

programming_language = "Rust";

println!("{} is programming language", programming_language);
// Out:
// Rust is programming language

// %% [markdown]
// ## Mutable variables
//
// * You can make a variable mutable by using the `mut` keyword

// %%
let mut count = 0;
println!("Initial count: {}", count);
count += 1;
println!("Updated count: {count}");
count += 1;
println!("Updated count: {count}");
// Out:
// Initial count: 0
// Updated count: 1
// Updated count: 2

// %% [markdown]
// ## Shadowing
//
// * You can declare a new variable with the same name as an existing variable, and the new variable will "shadow" the existing variable

// %%
fn main() { 
    let outer = 42; 
     { // start of code block 
          let inner = 3.14; 
          println!("block variable: {}", inner); 
          let outer = 99; // shadows the first outer variable 
          println!("block variable outer: {}", outer); 
      } // end of code block 
      println!("outer variable: {}", outer); 
  } 

  main();
// Out:
// block variable: 3.14
// block variable outer: 99
// outer variable: 42

// %% [markdown]
// ## Constants
//
// * Constants are:
//   * always immutable
//   * evaluated at compile time.
// * Constants can be declared in any scope, including the global scope
// * By convention, constants are named using uppercase letters with underscores separating words (e.g., `MAX_SIZE`).

// %%
const SECONDS_IN_MINUTE: u32 = 60;
const MINUTES_IN_HOUR: u32 = 60;
const SECONDS_IN_HOUR: u32 = SECONDS_IN_MINUTE * MINUTES_IN_HOUR;

// %%
println!("seconds in one hour: {}", SECONDS_IN_HOUR);
// Out:
// seconds in one hour: 3600

// %% [markdown]
// ## Static Variables
//
// * Rust also has static variables, which are similar to constants but have some differences:
//   * Lifetimes: static variables have a `'static` lifetime, meaning they live for the entire duration of the program.
//   * Mutability: static variables can be mutable if declared with static mut, but this requires unsafe code to access or modify them.

// %%
static MESSAGE: &str = "Hello Rust!";
static mut COUNTER: u32 = 0;

fn click() {
    unsafe {
        COUNTER += 1;
    }
}

fn main() {
    println!("{}", MESSAGE);
    click();
    click();
    unsafe {
        println!("COUNTER: {}", COUNTER);
    }
}

main();
// Out:
// [static_mut_refs] Error: creating a shared reference to mutable static
//     ╭─[ command_34:1:1 ]
//     │
//  15 │         println!("COUNTER: {}", COUNTER);
//     │                                 ───┬───
//     │                                    ╰───── shared reference to mutable static
// ────╯

// %% [markdown]
// ## Integer types
//
// | Length | Signed | Unsigned |
// |--------|--------|----------|
// | 8-bit  | i8     | u8       |
// | 16-bit | i16    | u16      |
// | 32-bit | i32    | u32      |
// | 64-bit | i64    | u64      |
// | 128-bit| i128   | u128     |
// | arch   | isize  | usize    |
//
// * the `isize` and `usize` types depend on the architecture of the computer your program is running on, which is denoted in the table as “arch”: 64 bits if you’re on a 64-bit architecture and 32 bits if you’re on a 32-bit architecture.

// %%
// signed integers
let int8: i8 = -128;
let int16: i16 = 32767;
let int32: i32 = 2147483647;
let int64: i64 = 9223372036854775807;
let int128: i128 = 170141183460469231731687303715884105727;
let intsize: isize = -1;  // depends on the architecture (32-bit or 64-bit)


// unsigned integers
let uint8: u8 = 255;
let uint16: u16 = 65535;
let uint32: u32 = 4294967295;
let uint64: u64 = 18446744073709551615;
let uint128: u128 = 340282366920938463463374607431768211455;
let uintsize: usize = 1;  // depends on the architecture (32-bit or 64-bit)

// %% [markdown]
// ### Type suffixes
//
// * You can specify integer literals using type suffixes, such as `13u8` or `13u16`.

// %%
let n = 42; // i32 by default
let f = 3.14; // f64 by default

// %%
let n = 43i32;
let clicks_number = 0u32;
let the_anwser = 42i64;

// %% [markdown]
// ### Number literals
//
// | Number literals | Example       |
// |-----------------|---------------|
// | Decimal         | 1_000_999     |
// | Hex             | 0xff          |
// | Octal           | 0o77          |
// | Binary          | 0b1111_0000   |
// | Byte (u8 only)  | b'A'          |

// %%
let one_million = 1_000_000;
let flag = 0xff;
let one_byte: u8 = 0b1111_0000;

// %% [markdown]
// ### Overflow
//
// * In debug mode, Rust includes checks for integer overflow. If overflow occurs, Rust will panic and exit the program.

// %%
let big_number: i32 = std::i32::MAX;
big_number
// Out:
// 2147483647

// %%
let next_number = big_number + 1; // panic: arithmetic operation overflowed
// Out:
// thread '<unnamed>' (4505) panicked at src/lib.rs:142:19:
// attempt to add with overflow
// stack backtrace:
//    0: __rustc::rust_begin_unwind
//              at /rustc/ed61e7d7e242494fb7057f2657300d9e77bb4fcb/library/std/src/panicking.rs:698:5
//    1: core::panicking::panic_fmt
//              at /rustc/ed61e7d7e242494fb7057f2657300d9e77bb4fcb/library/core/src/panicking.rs:75:14
//    2: core::panicking::panic_const::panic_const_add_overflow
//              at /rustc/ed61e7d7e242494fb7057f2657300d9e77bb4fcb/library/core/src/panicking.rs:175:17
//    3: run_user_code_28
//    4: evcxr::runtime::Runtime::run_loop
//    5: evcxr::runtime::runtime_hook
//    6: evcxr_jupyter::main
// note: Some details are omitted, run with `RUST_BACKTRACE=full` for a verbose backtrace.

// %% [markdown]
// * In release mode overflow will wrap to negative value (unlike in C++ where it is undefined behavior)
// * When you want to wrap arithemtic you can use `wrapping_add`, `wrapping_sub`, `wrapping_mul` etc.

// %%
let next_number = big_number.wrapping_add(1); // -2147483648
next_number
// Out:
// -2147483648

// %% [markdown]
// ## Floating point types
//
// * Rust’s floating-point types are:
//   * `f32` - 32 bits in size
//   * `f64` - 64 bits in size

// %%
fn main() {
    let x = 2.0; // f64 by default
    let y: f32 = 3.0; // f32

    // type suffixes
    let pi_double = 3.14159f64; 
    let pi_float = 3.14159f32;

    println!("x = {}, y = {y}, pi_double = {pi_double}, pi_float = {pi_float:0.2}", x);

    let _pi2 = dbg!(pi_float * 2.0f32);
}

main();
// Out:
// x = 2, y = 3, pi_double = 3.14159, pi_float = 3.14
// [src/lib.rs:14:16] pi_float * 2.0f32 = 6.28318

// %% [markdown]
// ### Constants and Math
//
// * The `std::f32` and `std::f64` define constants for IEEE-754 floating point numbers, such as `INFINITY`, `NEG_INFINITY`, `NAN`, `MIN` and `MAX`.
// * The `std::f64::consts` and `std::f32::consts` modules provide a number of useful constants, such as `PI` and `E`.

// %%
assert!((-1. / std::f32::INFINITY).is_sign_negative());

// %% [markdown]
// * The `f32` and `f64` types provide a full complement of methods for mathematical calculations, such as: `sqrt`, `exp`, `log`, `sin`, `cos`, `tan`, etc.
// * Calling these functions we have to explicitly provide a type hint (numeric type cannot be ambiguous)

// %%
assert_eq!(5f32.sqrt() * 5f32.sqrt(), 5.0);  
assert!((-1.01f64).floor() == -2.0);

// %%
(2.0).sqrt()
// Out:
// [E0689] Error: can't call method `sqrt` on ambiguous numeric type `{float}`
//    ╭─[ command_64:1:1 ]
//    │
//  1 │ (2.0).sqrt()
//    │  ─┬─  ──┬─
//    │   ╰───────── help: you must specify a concrete type for this numeric value, like `f32`: `2.0_f32`
//    │         │
//    │         ╰─── error: can't call method `sqrt` on ambiguous numeric type `{float}`
// ───╯
// [unused_variables] Error: unused variable: `y`
// [unused_variables] Error: unused variable: `pi_double`
// [unused_variables] Error: unused variable: `pi2`

// %%
println!("{}", (2.0f64).sqrt());
println!("{}", f64::sqrt(2.0));
// Out:
// 1.4142135623730951
// 1.4142135623730951

// %% [markdown]
// ## Numeric operations
//
// * Rust supports the standard arithmetic operators: `+`, `-`, `*`, `/`, and `%`.

// %% [markdown]
// * Addition

// %%
let sum = 5 + 10;
sum
// Out:
// 15

// %% [markdown]
// * Subtraction

// %%
let difference = 95.5 - 45.4;
difference
// Out:
// 50.1

// %% [markdown]
// * Multiplication

// %%
let product = 21 * 2;
product
// Out:
// 42

// %% [markdown]
// * Division

// %%
let quotient = 56.7 / 12.1;
quotient
// Out:
// 4.685950413223141

// %%
let truncated = 15 / 7;
truncated
// Out:
// 2

// %% [markdown]
// * Modulo

// %%
let reminder = 15 % 7;
reminder
// Out:
// 1

// %% [markdown]
// ### Compound assignment operators
//
// * Rust also supports compound assignment operators, such as `+=`, `-=`, `*=`, `/=`, and `%=`.

// %%
let mut x = 5f64;

x /= 2f64;

println!("x = {}", x);
// Out:
// x = 2.5

// %% [markdown]
// ## The Boolean Type
//
// * Rust has a built-in boolean type called `bool`. It has two possible values: `true` and `false`.

// %%
let mut is_ok: bool = true;

is_ok = false;

println!("is_ok={}", is_ok);
// Out:
// is_ok=false

// %% [markdown]
// * Rust `as` operator can be used to convert from a boolean to an integer

// %%
true as i32
// Out:
// 1

// %% [markdown]
// * Rust does not have automatic conversion from integers to booleans

// %%
1 as bool
// Out:
// [E0054] Error: cannot cast `i32` as `bool`

// %%
let n = 1;

let flag: bool = match n {
    0 => false,
    1 => true,
    _ => panic!("Unexpected value: {}", n),
};

flag
// Out:
// true

// %% [markdown]
// ## The Character Type
//
// * `char` char in Rust can represent any Unicode scalar value, including alphabetic characters, symbols, control characters, and more.
// * `char` literals are enclosed in single quotes ('A').

// %%
fn main() {
    let letter = 'A';  // A single character
    let emoji = '😊';  // An emoji character
    let special_character = 'ñ';  // A special alphabetic character

    println!("Letter: {}", letter);  // Output: Letter: A
    println!("Emoji: {}", emoji);    // Output: Emoji: 😊
    println!("Special Character: {}", special_character);  // Output: Special Character: ñ
}

main();
// Out:
// Letter: A
// Emoji: 😊
// Special Character: ñ

// %% [markdown]
// * `char` is always four bytes in size

// %%
std::mem::size_of::<char>()
// Out:
// 4

// %%
let v: Vec<char> = vec!['h', 'e', 'l', 'l', '😊'];

// five elements times four bytes for each element
assert_eq!(20, v.len() * std::mem::size_of::<char>());

// %% [markdown]
// ### Convertions for `char`:
// * from `u8` to `char`

// %%
let ascii_value = 65u8;
let character = ascii_value as char;
println!("Character: {}", character);  // Output: Character: A
// Out:
// Character: A

// %% [markdown]
// * from `char` to `u32` - ou can get the Unicode code point of a char using the `as` keyword.

// %%
let character = '😊';
let code_point = character as u32;
println!("Unicode code point: {}", code_point);
// Out:
// Unicode code point: 128522

// %% [markdown]
// ## Type checking and conversions

// %% [markdown]
// Rust does not allow implicit type conversion between numeric types. You can convert between types using the `as` keyword.

// %%
let score: i32 = 42;
let final_score: u32 = score;
// Out:
// [E0308] Error: mismatched types
//    ╭─[ command_99:1:1 ]
//    │
//  2 │ let final_score: u32 = score;
//    │                  ─┬─   ──┬──│
//    │                   ╰─────────── expected due to this
//    │                          │  │
//    │                          ╰──── expected `u32`, found `i32`
//    │                             │
//    │                             ╰─ help: you can convert an `i32` to a `u32` and panic if the converted value doesn't fit: `.try_into().unwrap()`
// ───╯

// %% [markdown]
// * Explicit conversion using `as` (also called a casting)

// %%
let score: i32 = 42;
let final_score: u32 = score as u32;

// %%
let n = 256;
let byte_value = n as u8; // This will wrap around to 0
println!("Byte value: {}", byte_value);  // Output: Byte value: 0
// Out:
// Byte value: 0

// %% [markdown]
// * Type must be convertible to the new type

// %%
let name = "32";
let id: i32 = name as i32;
// Out:
// [E0606] Error: casting `&str` as `i32` is invalid
//    ╭─[ command_104:1:1 ]
//    │
//  2 │ let id: i32 = name as i32;
//    │               ─────┬─────
//    │                    ╰─────── error: casting `&str` as `i32` is invalid
// ───╯

// %% [markdown]
// ### Conversion methods between types

// %% [markdown]
// | Mechanism | Direction | Fallible | Cost | Typical use |
// | --- | --- | --- | --- | --- |
// | **as** | primitives, pointers | maybe | low-level | numeric/pointer casts |
// | **From / Into** | owned → owned | no | maybe | safe, infallible conversions |
// | **TryFrom / TryInto** | owned → owned | yes | maybe | parsing, validation |
// | **AsRef / AsMut** | owned → ref | no | zero | generic APIs, no allocation |
// | **Borrow** | owned → ref | no | zero | collections, hashing |
// | **Deref** | smart ptr → ref | no | zero | ergonomics |
// | **Coercions** | implicit | no | zero | ergonomics |

// %% [markdown]
// ## Tuples
//
// * Tuples are a way of grouping together a number of values with a variety of types into one compound type.
// * Tuples have a fixed length: once declared, they cannot grow or shrink in size.

// %%
let person: (&str, &str, i32) = ("James", "Bond", 42);

// %%
println!("{:?}", person);
// Out:
// ("James", "Bond", 42)

// %% [markdown]
// * Tuples are indexed by position, starting at zero

// %%
person.0
// Out:
// "James"

// %%
person.1
// Out:
// "Bond"

// %%
person.2
// Out:
// 42

// %%
person.3
// Out:
// [E0609] Error: no field `3` on type `(&str, &str, i32)`
//    ╭─[ command_119:1:1 ]
//    │
//  1 │ person.3
//    │        ┬
//    │        ╰── unknown field
// ───╯

// %% [markdown]
// * Destructuring a tuple

// %%
let person: (&str, &str, i32) = ("James", "Bond", 42);
let (first, last, age) = person;
println!("first={}, last={last}, age={age}", first);
// Out:
// first=James, last=Bond, age=42

// %%
let (fname, lname, ..) = person;
println!("{fname} {lname}");

let (.., lname, age) = person;
println!("{lname} is {age} years old");

let (fname, .., age) = person;
println!("{fname} is {age}");
// Out:
// James Bond
// Bond is 42 years old
// James is 42

// %%
let v = vec![1, 2, 3, 4, 5];

let (first, second) : (&str, Vec<i32>) = ("vector with items", v);

println!("{}: {:?}", first, second);
// Out:
// vector with items: [1, 2, 3, 4, 5]

// %%
{
    let mut name: String = "John".to_string();
    name.push_str(" Paul");

    let (first_name, last_name): (&mut String, &str) = (&mut name, "Smith");

    println!("first_name: {}, last_name: {}", first_name, last_name);
    first_name.push_str(" IV");

    println!("name: {}", name);
}
// Out:
// first_name: John Paul, last_name: Smith
// name: John Paul IV
// ()

// %% [markdown]
// ## Unit
//
// * The tuple without any values has a special name, **unit**. This value and its corresponding type are both written `()` and represent an empty value or an empty return type.
// * Expressions implicitly return the unit value if they don’t return any other value.

// %%
let unit: () = ();

if unit == () {
    println!("This will always be printed");
} else {
    println!("This will never be printed");
}
// Out:
// This will always be printed
// ()

// %% [markdown]
// # Functions

// %% [markdown]
// * Functions in Rust are declared using the `fn` keyword, followed by the function name and a pair of parentheses that may include parameters. The function body is enclosed in curly braces `{}`.
// * Functions can return values using the `return` keyword or by omitting it and leaving the value as the last expression in the function body. The return type of a function is specified after an arrow `->` following the parameter list.

// %%
fn add(a: i32, b: i32) -> i32 {
    return a + b;
}

fn multiply(a: i32, b: i32) -> i32 {
    a * b
}

let sum = add(1, 2);
println!("sum: {}", sum);

println!("product: {}", multiply(3, 4));
// Out:
// sum: 3
// product: 12

// %%
fn full_name(fname: &str, lname: &str) -> String {
    fname.to_owned() + " " + lname
}

let first_name = "Jan";

let person: String = full_name(first_name, "Kowalski");
person
// Out:
// "Jan Kowalski"

// %% [markdown]
// * When function does not return a value, it implicitly returns the unit type `()`. In this case, you can omit the return type in the function signature.

// %%
fn returns_unit() -> () {
    return;
}

fn implictly_returns_unit() {
    return;
}

// %%
assert_eq!(returns_unit(), implictly_returns_unit());

// %% [markdown]
// * Function that never returns is denoted with the `!` type, which is called the "never" type. This is used for functions that always panic or loop indefinitely.

// %%
fn never_ends() -> ! {
    loop {
        panic!("Now I exit!!!");
    }
}

never_ends();
// Out:
// thread '<unnamed>' (37167) panicked at src/lib.rs:12:9:
// Now I exit!!!
// stack backtrace:
//    0: __rustc::rust_begin_unwind
//              at /rustc/ed61e7d7e242494fb7057f2657300d9e77bb4fcb/library/std/src/panicking.rs:698:5
//    1: core::panicking::panic_fmt
//              at /rustc/ed61e7d7e242494fb7057f2657300d9e77bb4fcb/library/core/src/panicking.rs:75:14
//    2: ctx::never_ends
//    3: core::ops::function::FnOnce::call_once
//    4: <core::panic::unwind_safe::AssertUnwindSafe<F> as core::ops::function::FnOnce<()>>::call_once
//    5: __rust_try
//    6: run_user_code_9
//    7: evcxr::runtime::Runtime::run_loop
//    8: evcxr::runtime::runtime_hook
//    9: evcxr_jupyter::main
// note: Some details are omitted, run with `RUST_BACKTRACE=full` for a verbose backtrace.

// %% [markdown]
// ## Function pointers
//
// * Types of function pointers are denoted using the `fn` keyword followed by the function signature. For example, `fn(i32) -> i32` represents a function pointer that takes an `i32` as an argument and returns an `i32`.

// %%
fn calculate(a: i32, b: i32, operation: fn(i32, i32) -> i32) -> i32 {
    operation(a, b)
}

// %%
calculate(3, 5, add)
// Out:
// 8

// %%
calculate(3, 5, multiply)
// Out:
// 15

// %%
let n = 256;

let un: u8 = u8::try_from(n).unwrap_or_else(|_| {
    println!("Value {} is out of range for u8", n);
    0
});
// Out:
// Value 256 is out of range for u8
